# %%
import sys
import pandas as pd
import numpy as np

print("Python Version:", sys.version)
print("Pandas Version:", pd.__version__)
print("Numpy Version:", np.__version__)
print("Python Executable Path:", sys.executable)
# Out:
# Python Version: 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 08:28:27) [Clang 14.0.6 ]
# Pandas Version: 3.0.1
# Numpy Version: 2.4.2
# Python Executable Path: /Users/mannyguevara/Documents/portfolio-projects/healthcare-revenue-sustainability/venv/bin/python
